# %% [markdown]
# <a href="https://colab.research.google.com/github/AnnaSafaryan/Translator/blob/master/Training-deps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Restart runtime, чтобы увидел seq2seq

# %%
from os import makedirs  # создание папок (в т.ч. промежуточных)
import sys
from json import dump
from keras.models import Sequential  # последовательная модель
from keras.layers import LSTM, Dense, Embedding, TimeDistributed  # слои
from keras.callbacks import ModelCheckpoint  # сохранялка
from seq2seq import Seq2Seq, AttentionSeq2Seq  # \\архитектуры seq2seq
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
import sys
sys.path.append('/content/gdrive/My Drive/Colab Notebooks/Курач')

# %%
from dater import load_config, add_config, load_data

# %%
from preprocessing import fit_on_texts, clean_test, show_stats, gen_to_train, gen_to_val, get_vectors

# %%
config = load_config(colab=True)
# Out:
# CONFIG
# corpus_name: tatoeba
# direction: en-ru
# train_len: 24000
# test_len: 6000
# model_type: standard
# epochs: 30
# batch_size: 16
# embed_len: 300
# depth_size: 2
# latent_dim: 256
# corpus_len: 291172
# src_len: 6
# src_vocab: 3456
# w2i_src: {'pdng': 0, 'unk': 1, 'kind': 2, 'inbox': 3, 'virus': 4, 'bribe': 5, 'easy': 6, 'writes': 7, 'yes-man': 8, 'exist': 9, 'doable': 10, 'drawn': 11, 'powerful': 12, 'agent': 13, 'beats': 14, 'choice': 15, 'label': 16, 'detained': 17, 'dreaming': 18, 'snowman': 19, 'sometime': 20, 'graduated': 21, '223-1374': 22, 'gimmick': 23, 'paper': 24, 'cake': 25, 'stuff': 26, 'fall': 27, 'blushing': 28, 'rule': 29, 'pun': 30, 'hopeless': 31, 'quietly': 32, 'tests': 33, 'listen': 34, 'denied': 35, 'enough': 36, 'straighten': 37, 'volunteer': 38, 'bullet': 39, 'avoiding': 40, 'world': 41, 'twenty-five': 42, 'approve': 43, 'housewife': 44, 'twitter': 45, 'hasty': 46, 'speech': 47, 'gym': 48, 'wrong': 49, 'until': 50, 'frowned': 51, 'burned': 52, 'song': 53, 'drenched': 54, 'talk': 55, 'witty': 56, 'ready': 57, 'relaxed': 58, 'baby': 59, 'early': 60, 'guarantee': 61, 'pagoda': 62, 'hungarian': 63, 'vision': 64, 'louder': 65, 'blessed': 66, 'resigning': 67, 'nine': 68, 'shut': 69, 'kissed': 70, 'envious': 71, 'pilots': 72, 'brother': 73, 'upbeat': 74, 'mouth': 75, 'rang': 76, 'classes': 77, 'stare': 78, 'climb': 79, 'mugged': 80, 'ajar': 81, 'enthusiastic': 82, 'which': 83, 'opened': 84, 'tuesday': 85, 'john': 86, 'armed': 87, 'autumn': 88, 'hint': 89, 'feared': 90, 'resign': 91, 'stranger': 92, 'cleaning': 93, 'watched': 94, 'message': 95, 'singer': 96, 'shy': 97, 'things': 98, 'weapon': 99, 'absent': 100, 'yawn': 101, 'turn': 102, 'agrees': 103, 'glad': 104, 'honest': 105, 'focus': 106, 'broccoli': 107, 'explained': 108, 'gardener': 109, 'all': 110, 'today': 111, 'reacted': 112, 'kicked': 113, 'cheating': 114, 'spread': 115, 'ours': 116, 'touching': 117, 'hitting': 118, 'watered': 119, 'exaggerating': 120, 'and': 121, '1960': 122, 'bake': 123, 'glasses': 124, 'toes': 125, 'packing': 126, 'corrected': 127, 'called': 128, 'fist': 129, 'cares': 130, 'slept': 131, 'direct': 132, 'sweat': 133, 'unhappy': 134, 'testify': 135, 'existed':
', '53': 'song', '54': 'drenched', '55': 'talk', '56': 'witty', '57': 'ready', '58': 'relaxed', '59': 'baby', '60': 'early', '61': 'guarantee', '62': 'pagoda', '63': 'hungarian', '64': 'vision', '65': 'louder', '66': 'blessed', '67': 'resigning', '68': 'nine', '69': 'shut', '70': 'kissed', '71': 'envious', '72': 'pilots', '73': 'brother', '74': 'upbeat', '75': 'mouth', '76': 'rang', '77': 'classes', '78': 'stare', '79': 'climb', '80': 'mugged', '81': 'ajar', '82': 'enthusiastic', '83': 'which', '84': 'opened', '85': 'tuesday', '86': 'john', '87': 'armed', '88': 'autumn', '89': 'hint', '90': 'feared', '91': 'resign', '92': 'stranger', '93': 'cleaning', '94': 'watched', '95': 'message', '96': 'singer', '97': 'shy', '98': 'things', '99': 'weapon', '100': 'absent', '101': 'yawn', '102': 'turn', '103': 'agrees', '104': 'glad', '105': 'honest', '106': 'focus', '107': 'broccoli', '108': 'explained', '109': 'gardener', '110': 'all', '111': 'today', '112': 'reacted', '113': 'kicked', '114': 'cheating', '115': 'spread', '116': 'ours', '117': 'touching', '118': 'hitting', '119': 'watered', '120': 'exaggerating', '121': 'and', '122': '1960', '123': 'bake', '124': 'glasses', '125': 'toes', '126': 'packing', '127': 'corrected', '128': 'called', '129': 'fist', '130': 'cares', '131': 'slept', '132': 'direct', '133': 'sweat', '134': 'unhappy', '135': 'testify', '136': 'existed', '137': 'weight', '138': 'evening', '139': 'b', '140': 'smells', '141': 'rush', '142': 'dressed', '143': 'approached', '144': 'bug', '145': 'justice', '146': 'monster', '147': 'tends', '148': 'applauded', '149': 'lecherous', '150': 'smoker', '151': 'upset', '152': 'freshman', '153': 'entered', '154': 'jazz', '155': 'test', '156': 'exercises', '157': 'donut', '158': 'brothers', '159': 'overworked', '160': 'talkative', '161': 'aches', '162': 'often', '163': 'stuffed', '164': 'windy', '165': 'movie', '166': 'help', '167': 'ice', '168': 'miss', '169': 'board', '170': 'humiliated', '171': 'motivated', '172': 'gymnast', '173': 'divorce', '174': 'pal', '175': 'spoiled', '176': 'frying', '177': 'comb', '178': 'kidding', '179': 'tomboy', '180': 'lazy', '181': 'novel', '182': 'succeeded', '183': 'interfere', '184': 'ex', '185': 'canceled', '186': 'clever', '187': 'return', '188': 'shouted', '189': 'meals', '190': 'it', '191': 'adults', '192': 'screams', '193': 'paris', '194': 'hurry', '195': 'japanese', '196': 'pizza', '197': 'looking', '198': 'pie', '199': 'rewrote', '200': 'twitches', '201': 'smell', '202': 'visit', '203': 'grab', '204': 'active', '205': 'cough', '206': 'single', '207': 'thank', '208': 'wire', '209': 'awake', '210': 'grouch', '211': 'amused', '212': 'prepare', '213': 'problem', '214': 'insomnia', '215': 'purple', '216': 'mean', '217': 'heavy', '218': 'sung', '219': 'pool', '220': 'fire', '221': 'havenot', '222': 'merry', '223': 'pointed', '224': 'catholic', '225': 'melodramatic', '226': 'last', '227': 'knife', '228': 'break', '229': 'blacked', '230': 'books', '231': 'bribed', '232': 'respect', '233': 'sports', '234': 'expected', '235': 'politely', '236': 'week', '237': 'captured', '238': 'correct', '239': 'untalented', '240': ' ...
# tar_len: 9
# tar_vocab: 9007
 'пеку': 165, 'наблюдает': 166, 'деликатно': 167, 'свое': 168, 'получаю': 169, 'злые': 170, 'хлопнул': 171, 'ходит': 172, 'оскорблением': 173, 'конфисковал': 174, 'заставляешь': 175, 'всему': 176, 'сделаете': 177, 'животных': 178, 'деньгах': 179, 'потрогать': 180, 'самоуверен': 181, 'знакома': 182, 'честолюбивая': 183, 'молока': 184, 'заверши': 185, 'нужны': 186, 'уезжать': 187, 'рыгнул': 188, 'замечательный': 189, 'поспать': 190, 'невезучая': 191, 'пытаюсь': 192, 'обнимите': 193, 'должен': 194, 'войны': 195, 'дразните': 196, 'реалистом': 197, 'невосприимчива': 198, 'слышно': 199, 'сюрпризы': 200, 'не': 201, 'пятерых': 202, 'застрахованы': 203, 'вежлив': 204, 'бессонница': 205, 'испугана': 206, 'провоцируй': 207, 'потеряла': 208, 'рождения': 209, 'редкость': 210, 'дразнюсь': 211, 'спят': 212, 'бессильна': 213, 'прикалывается': 214, 'преподавать': 215, 'бродяга': 216, 'переделай': 217, 'пройдись': 218, 'унывай': 219, 'думайте': 220, 'одержали': 221, 'опаздывают': 222, 'отпустила': 223, 'пьеса': 224, 'обжёгся': 225, 'праздников': 226, 'блондинки': 227, 'любишь': 228, 'своем': 229, 'идите': 230, 'сработало': 231, 'услышала': 232, 'случиться': 233, 'наивные': 234, 'безнадежен': 235, 'польщённой': 236, 'знаменита': 237, 'книги': 238, 'живу': 239, 'ошеломлён': 240, 'китаянка': 241, 'напугана': 242, 'мальчик': 243, 'хотел': 244, 'пожали': 245, 'учитс ...
# i2w_tar: {'0': 'pdng', '1': 'unk', '2': 'импровизировал', '3': 'уволюсь', '4': 'глубокое', '5': 'слуга', '6': 'секрет', '7': 'закончила', '8': 'абсолютно', '9': 'ленивые', '10': 'двигайтесь', '11': 'вызовите', '12': 'разговаривала', '13': 'ненавидели', '14': 'гений', '15': 'сторон', '16': 'зарегистрировался', '17': 'безнадёжен', '18': 'найди', '19': 'отсюда', '20': 'слух', '21': 'перепил', '22': 'японец', '23': 'играют', '24': 'убирайся', '25': 'звук', '26': 'бояться', '27': 'тяжёлое', '28': 'магазинам', '29': 'поговорить', '30': 'заключённая', '31': 'побуду', '32': 'разрешите', '33': 'колодец', '34': 'автомобиль', '35': 'беспокоится', '36': 'американец', '37': 'мешайте', '38': 'похудел', '39': 'полностью', '40': 'пользовались', '41': 'жара', '42': 'плаваю', '43': 'вяжу', '44': 'болят', '45': 'сам', '46': 'честь', '47': 'последним', '48': 'автомобилями', '49': 'вызвано', '50': 'дурой', '51': 'сны', '52': 'идёте', '53': 'испанец', '54': 'груба', '55': 'пахнет', '56': 'уродлив', '57': 'повёл', '58': 'мог', '59': 'укажи', '60': 'слюнтяй', '61': 'злишься', '62': 'азербайджанец', '63': 'поблагодарю', '64': 'боксеры', '65': 'приглашён', '66': 'тонет', '67': 'поверил', '68': 'милосердна', '69': 'целовать', '70': 'подмогой', '71': 'аккуратный', '72': 'вставать', '73': 'мне', '74': 'перезвонил', '75': 'хай', '76': 'встать', '77': 'решать', '78': 'пляж', '79': 'плохого', '80': 'кем', '81': 'небольшой', '82': 'радиоприёмники', '83': 'изобретателен', '84': 'этикетку', '85': 'микрофон', '86': 'собственным', '87': 'мёртвая', '88': 'заражён', '89': 'курильщик', '90': 'гимнаст', '91': 'хихикал', '92': 'джинсы', '93': 'никого', '94': 'когда-то', '95': 'поднимаюсь', '96': 'эксперт', '97': 'остаёмся', '98': 'принесите', '99': 'ровесницы', '100': 'выиграл', '101': 'усыновили', '102': 'закончится', '103': 'настроен', '104': 'лентяй', '105': 'замолчал', '106': 'напоминайте', '107': 'наличные', '108': 'самодовольством', '109': 'бесстрашны', '110': 'несчастна', '111': 'пригласи', '112': 'жестоки', '113': 'конечно', '114': 'заметили', '115': 'старайся', '116': 'авантюрен', '117': 'ошибки', '118': 'удовлетворённый', '119': 'лодку', '120': 'завяжите', '121': 'отчитала', '122': 'наказали', '123': 'обоих', '124': 'готовит', '125': 'дай-ка', '126': 'страдаю', '127': 'грустные', '128': 'отворилась', '129': 'задыхалась', '130': 'зевает', '131': 'выпусти', '132': 'умеет', '133': 'голой', '134': 'закрывать', '135': 'таращиться', '136': 'семнадцать', '137': 'водить', '138': 'комнату', '139': 'надул', '140': 'повторите', '141': 'постараюсь', '142': 'лгать', '143': 'языках', '144': 'краснеешь', '145': 'знакомо', '146': 'одинаково', '147': 'певец', '148': 'скажу', '149': 'модель', '150': 'горел', '151': 'скупым', '152': 'обеспокоен', '153': 'живей', '154': 'исключено', '155': 'напиток', '156': 'начальника', '157': 'финн', '158': 'приезжай', '159': 'изготавливаю', '160': 'чувак', '161': 'низкая', '162': 'парализована', '163': 'тётя', '164': 'хамите', '165': 'пеку', '166': 'наблюдает', '167': 'деликатно', '168': 'свое', '169': 'получаю', '170': 'злые', '171': 'хлопнул', '172': 'ходит', '173': 'оскорблением', '174': 'конфисковал', '175': 'заставляешь', '176': 'всему', '177': 'сделаете', '178': 'животных', '179': 'деньгах', '180': 'потрогать', '181': 'самоуверен', '182': 'знакома', '183': 'честолюбивая', '184': 'молока', '185': 'заверши', '186': 'нужны', '187': 'уезжать', '188': 'рыгнул', '189': 'замечательный', '190': 'поспать', '191': 'невезучая', '192': 'пытаюсь', '193': 'обнимите', '194': 'должен', '195': 'войны', '196': 'дразните', '197': 'реалистом', '198': 'невосприимчива', '199': 'слышно', '200': 'сюрпризы', '201': 'не', '202': 'пятерых', '203': 'застрахованы', '204': 'вежлив', '205': 'бессонница', '206': 'испугана', '207': 'провоцируй', '208': 'потеряла', '209': 'рождения', '210': 'редкость', '211': 'дразнюсь', '212': 'спят', '213': 'бессильна', '214': 'прикалывается', '215': 'преподавать', '216': 'бродяга', '217': 'переделай', '218': 'пройдись', '219': 'уныв ...
# data_path: /content/gdrive/My Drive/Colab Notebooks/Курач/en-ru_standard_bow2/e=10_b=16_d=1_h=256_emb=300
# train_steps: 1500
# test_steps: 375
# best_epoch: 10
# vec_type: deps
# src_mlen: 3.0
# tar_mlen: 3.0

# %%
# загружаем данные
train = load_data(config['direction'], corpus_type='train', colab=True)
print(train.shape)
#print(train[:5])
train_src = train[:, 0]
train_tar = train[:, 1]
# Out:
# (24000, 2)

# %%
test = load_data(config['direction'], corpus_type='test', colab=True)
print(test.shape)
#print(test[:3])
test_src = test[:, 0]
test_tar = test[:, 1]
# Out:
# (6000, 2)

# %%
src_len, src_mlen, src_vocab, w2i_src, i2w_src = fit_on_texts(train_src)

# %%
tar_len, tar_mlen, tar_vocab, w2i_tar, i2w_tar = fit_on_texts(train_tar)

# %%
test_len, test_mlen, clean_test_src, voc_dif, pr_voc_dif, tok_dif, pr_tok_dif = clean_test(test_src, w2i_src)
# Out:
# Cleaning...

# %%
del(test_src)

# %%
add_config('src_len', src_len, config=config, colab=True)
add_config('src_mlen', src_mlen, config=config, colab=True)
add_config('src_vocab', src_vocab, config=config, colab=True)
add_config('w2i_src', w2i_src, config=config, colab=True)
add_config('i2w_src', i2w_src, config=config, colab=True)
add_config('tar_len', tar_len, config=config, colab=True)
add_config('tar_mlen', tar_mlen, config=config, colab=True)
add_config('tar_vocab', tar_vocab, config=config, colab=True)
add_config('w2i_tar', w2i_tar, config=config, colab=True)
add_config('i2w_tar', i2w_tar, config=config, colab=True)

# %%
del(w2i_src)
del(i2w_src)
del(w2i_tar)
del(i2w_tar)

# %%
#print(clean_test_src)

# %%
show_stats(config, pr_voc_dif, voc_dif, tok_dif, pr_tok_dif)
# Out:
# 	Src maxlen:	6
# 	Src medlen:	3.0
# 	Src vocab:	3456
# 	Tar maxlen:	9
# 	Tar medlen:	3.0
# 	Tar vocab:	9007
# 	11.56% тестового словаря (233 слов) нет в тренировочном. Это 260 токенов -- 1.27% тестового корпуса.

# %%
# создаём папку для этой модели
# путь к папке с данными
data_path = '/content/gdrive/My Drive/Colab Notebooks/Курач/{}_{}_{}/e={}_b={}_d={}_h={}_emb={}'.format(config['direction'], config['model_type'], config['vec_type'], config['epochs'],
                                                       config['batch_size'], config['depth_size'], config['latent_dim'],
                                                       config['embed_len'])

# %%
print(data_path, '\n')
add_config('data_path', data_path,config=config,  colab=True)
try:  # пробуем создать папку
    makedirs(data_path+'/model')  # создаём цепочку папок
except OSError:  # если папка уже есть
    pass  # ничего не делаем
# Out:
# /content/gdrive/My Drive/Colab Notebooks/Курач/en-ru_standard_deps/e=30_b=16_d=2_h=256_emb=300

# %%
# Вывод схемы модели в файл
def sum_to_file(model):
    tmpout = sys.stdout  # сохраняем системный вывод
    fileout = open(data_path + '/' + 'summary.txt', 'w')  # переназначаем в файл
    sys.stdout = fileout
    model.summary()
    fileout.close()
    sys.stdout = tmpout  # возвращаем системный вывод

# %%
def vis(key, history):
    history_dict = history.history
    values = history_dict[key]
    val_values = history_dict['val_{}'.format(key)]

    epochs = range(1, len(history_dict[key]) + 1)

    plt.plot(epochs, values, 'bo', label='Training {}'.format(key))
    plt.plot(epochs, val_values, 'ro', label='Validation {}'.format(key))
    plt.title('Training and validation {}'.format(key))
    plt.xlabel('Epochs')
    plt.ylabel(key.capitalize())
    plt.legend()

    plt.show()

# %%
# определяем модель
def define_seq2seq_model(model_type, src_vocab, tar_vocab, src_len, tar_len, batch_size, embeddings):
    # src_vocab: объём исходного словаря
    # tar_vocab: объём конечного словаря
    # src_len: максимальная длина исходного предложения, оно же -- src_timesteps \\разве и тут будет, не только в конечных?
    # tar_len: максимальная длина конечного предложения, оно же -- tar_timesteps \\(сколько раз TimeDistributed будет "наматывать" новые слова в последовательность через Dense)

    # print("\nParams:\n model_type={} \n src_vocab={} \t tar_vocab={} \n src_len (timesteps) = {} \t tar_len (timesteps) = {}".format(model_type, src_vocab, tar_vocab, src_len, tar_len)) #\\перепиши

    # заводим последовательную модельку
    model = Sequential()

    # 1: пропускаем исходный словарь через слой Embedding \\распиши
    model.add(Embedding(src_vocab, config['embed_len'], input_length=src_len, weights=[embeddings], trainable=False))

    # 2: собственно Seq2Seq слой \\распиши
    if model_type == 'standard':
        model.add(Seq2Seq(batch_input_shape=(batch_size, src_len, config['embed_len']),
                          output_length=tar_len, output_dim=tar_vocab,
                          hidden_dim=config['latent_dim'], depth=config['depth_size'],
                          peek=False))
    elif model_type == 'peeky':
        model.add(Seq2Seq(batch_input_shape=(batch_size, src_len, config['embed_len']),
                          output_length=tar_len, output_dim=tar_vocab,
                          hidden_dim=config['latent_dim'], depth=config['depth_size'],
                          peek=True))
    elif model_type == 'attention':  # \\ValueError: Shapes must be equal rank, but are 2 and 3 for
        model.add(AttentionSeq2Seq(batch_input_shape=(batch_size, src_len, config['embed_len']),
                                   output_length=tar_len, output_dim=tar_vocab,
                                   hidden_dim=config['latent_dim'], depth=config['depth_size']))
    else:
        print(
            '\nUnknown Model Type\nModel Types:\n"standard" for Seq2Seq\n"peeky" for Seq2Seq + peek=True\n"attention" for AttentionSeq2Seq')

    # 3: слой TimeDistributed \\опиши
    model.add(TimeDistributed(Dense(tar_vocab, activation='softmax')))

    # компилируемся \\разбери
    model.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['acc'])
    # optimizer: adam
    # loss: categorical_crossentropy
    
    # выводим схему модели
    model.summary()

    # plot_model(model, to_file='model.png', show_shapes=True) #\\полезная штука, разберись + что ещё умеет?
    return model

# %%
embed_matrix = get_vectors(config['w2i_src'], config['vec_type'], colab=True)
#embed_matrix[:10]

# %%
# заводим модель, указываем параметры
model = define_seq2seq_model(config['model_type'], config['src_vocab'], config['tar_vocab'], config['src_len'],
                             config['tar_len'], config['batch_size'], embed_matrix)
sum_to_file(model)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2885: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 6, 300)            1036800
# _________________________________________________________________
# model_15 (Model)             (16, 9, 9007)             27044749
# _________________________________________________________________
# time_distributed_2 (TimeDist (16, 9, 9007)             81135056
# =================================================================
# Total params: 109,216,605
# Trainable params: 108,179,805
# Non-trainable params: 1,036,800
# _________________________________________________________________

# %%
train_steps = int(config['train_len'] / config['batch_size'])  # считаем шаги для генератора
print(train_steps)
add_config('train_steps', train_steps, config=config, colab=True)
test_steps = int(config['test_len'] / config['batch_size'])
print(test_steps)
add_config('test_steps', test_steps, config=config, colab=True)
# Out:
# 1500
# 375

# %%
# обучаемся \\распиши
# \\как форматировать такое название?
checkpoint = ModelCheckpoint(data_path + '/model/' + 'weights-{epoch:1d}.h5', monitor='val_loss', verbose=1,
                             save_best_only=False, mode='min', save_weights_only=True)

# %%
history = model.fit_generator(gen_to_train(train_src, train_tar, config),
                    steps_per_epoch = train_steps,
                    validation_data = gen_to_val(clean_test_src, test_tar, config),
                    validation_steps = test_steps,
                    epochs=config['epochs'], callbacks=[checkpoint], verbose=1)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/30
# 1499/1500 [============================>.] - ETA: 0s - loss: 2.4544 - acc: 0.0286Epoch 00001: saving model to /content/gdrive/My Drive/Colab Notebooks/Курач/en-ru_standard_deps/e=30_b=16_d=2_h=256_emb=300/model/weights-1.h5
# 1500/1500 [==============================] - 701s 468ms/step - loss: 2.4545 - acc: 0.0286 - val_loss: 2812.5914 - val_acc: 0.0315
# Epoch 2/30
# 1499/1500 [============================>.] - ETA: 0s - loss: 3.5446 - acc: 0.0277Epoch 00002: saving model to /content/gdrive/My Drive/Colab Notebooks/Курач/en-ru_standard_deps/e=30_b=16_d=2_h=256_emb=300/model/weights-2.h5
# 1500/1500 [==============================] - 693s 462ms/step - loss: 3.5446 - acc: 0.0277 - val_loss: 2915.4414 - val_acc: 0.0134
# Epoch 3/30
# 1499/1500 [============================>.] - ETA: 0s - loss: 4.0106 - acc: 0.0322Epoch 00003: saving model to /content/gdrive/My Drive/Colab Notebooks/Курач/en-ru_standard_deps/e=30_b=16_d=2_h=256_emb=300/model/weights-3.h5
# 1500/1500 [==============================] - 695s 463ms/step - loss: 4.0103 - acc: 0.0322 - val_loss: 2915.4133 - val_acc: 0.0141
# Epoch 4/30
# 1499/1500 [============================>.] - ETA: 0s - loss: 4.0050 - acc: 0.0310Epoch 00004: saving model to /content/gdrive/My Drive/Colab Notebooks/Курач/en-ru_standard_deps/e=30_b=16_d=2_h=256_emb=300/model/weights-4.h5
# 1500/1500 [==============================] - 692s 461ms/step - loss: 4.0047 - acc: 0.0310 - val_loss: 2915.3326 - val_acc: 0.0347
# Epoch 5/30
# 1499/1500 [============================>.] - ETA: 0s - loss: 3.7794 - acc: 0.0274Epoch 00005: saving model to /content/gdrive/My Drive/Colab Notebooks/Курач/en-ru_standard_deps/e=30_b=16_d=2_h=256_emb=300/model/weights-5.h5
# 1500/1500 [==============================] - 696s 464ms/step - loss: 3.7796 - acc: 0.0274 - val_loss: 2916.3886 - val_acc: 0.0269
# Epoch 6/30
# 1499/1500 [============================>.] - ETA: 0s - loss: 4.1210 - acc: 0.0319Epoch 00006: saving model to /content/gdrive/My Drive/Colab Notebooks/Курач/en-ru_standard_deps/e=30_b=16_d=2_h=256_emb=300/model/weights-6.h5
# 1500/1500 [==============================] - 695s 464ms/step - loss: 4.1208 - acc: 0.0320 - val_loss: 2916.0284 - val_acc: 0.0354
# Epoch 7/30
# 1499/1500 [============================>.] - ETA: 0s - loss: 4.0638 - acc: 0.0208Epoch 00007: saving model to /content/gdrive/My Drive/Colab Notebooks/Курач/en-ru_standard_deps/e=30_b=16_d=2_h=256_emb=300/model/weights-7.h5
# 1500/1500 [==============================] - 695s 463ms/step - loss: 4.0645 - acc: 0.0208 - val_loss: 2918.6623 - val_acc: 1.4815e-04
# Epoch 8/30
# 1499/1500 [============================>.] - ETA: 0s - loss: 5.1873 - acc: 2.5017e-04Epoch 00008: saving model to /content/gdrive/My Drive/Colab Notebooks/Курач/en-ru_standard_deps/e=30_b=16_d=2_h=256_emb=300/model/weights-8.h5
# 1500/1500 [==============================] - 691s 461ms/step - loss: 5.1873 - acc: 2.5000e-04 - val_loss: 2918.6623 - val_acc: 1.4815e-04
# Epoch 9/30
# 1499/1500 [============================>.] - ETA: 0s - loss: 5.1873 - acc: 2.5017e-04Epoch 00009: saving model to /content/gdrive/My Drive/Colab Notebooks/Курач/en-ru_standard_deps/e=30_b=16_d=2_h=256_emb=300/model/weights-9.h5
# 1500/1500 [==============================] - 691s 461ms/step - loss: 5.1873 - acc: 2.5000e-04 - val_loss: 2918.6623 - val_acc: 1.4815e-04
# Epoch 10/30
# 1499/1500 [============================>.] - ETA: 0s - loss: 5.1873 - acc: 2.5017e-04Epoch 00010: saving model to /content/gdrive/My Drive/Colab Notebooks/Курач/en-ru_standard_deps/e=30_b=16_d=2_h=256_emb=300/model/weights-10.h5
# 1500/1500 [==============================] - 691s 460ms/step - loss: 5.1873 - acc: 2.5000e-04 - val_loss: 2918.6623 - val_acc: 1.4815e-04
# Epoch 11/30
# 1499/1500 [============================>.] - ETA: 0s - loss: 5.1873 - acc: 2.5017e-04Epoch 00011: saving model to /content/gdrive/My Drive/Colab Notebooks/Курач/en-ru_standard_deps/e=30_b=16_d=2_h=256_emb=300/model/weights-11.h5
# 1500/1500 [==============================] - 689s 459ms/step - loss: 5.1873 - acc: 2.5000e-04 - val_loss: 2918.6623 - val_acc: 1.4815e-04
# Epoch 12/30
# 1499/1500 [============================>.] - ETA: 0s - loss: 5.1873 - acc: 2.5017e-04Epoch 00012: saving model to /content/gdrive/My Drive/Colab Notebooks/Курач/en-ru_standard_deps/e=30_b=16_d=2_h=256_emb=300/model/weights-12.h5
# 1500/1500 [==============================] - 685s 457ms/step - loss: 5.1873 - acc: 2.5000e-04 - val_loss: 2918.6623 - val_acc: 1.4815e-04
# Epoch 13/30
# 1499/1500 [============================>.] - ETA: 0s - loss: 5.1873 - acc: 2.5017e-04Epoch 00013: saving model to /content/gdrive/My Drive/Colab Notebooks/Курач/en-ru_standard_deps/e=30_b=16_d=2_h=256_emb=300/model/weights-13.h5
# 1500/1500 [==============================] - 685s 457ms/step - loss: 5.1873 - acc: 2.5000e-04 - val_loss: 2918.6623 - val_acc: 1.4815e-04
# Epoch 14/30
# 1499/1500 [============================>.] - ETA: 0s - loss: 5.1873 - acc: 2.5017e-04Epoch 00014: saving model to /content/gdrive/My Drive/Colab Notebooks/Курач/en-ru_standard_deps/e=30_b=16_d=2_h=256_emb=300/model/weights-14.h5
# 1500/1500 [==============================] - 686s 457ms/step - loss: 5.1873 - acc: 2.5000e-04 - val_loss: 2918.6623 - val_acc: 1.4815e-04
# Epoch 15/30
# 1499/1500 [============================>.] - ETA: 0s - loss: 5.1873 - acc: 2.5017e-04Epoch 00015: saving model to /content/gdrive/My Drive/Colab Notebooks/Курач/en-ru_standard_deps/e=30_b=16_d=2_h=256_emb=300/model/weights-15.h5
# 1500/1500 [==============================] - 686s 458ms/step - loss: 5.1873 - acc: 2.5000e-04 - val_loss: 2918.6623 - val_acc: 1.4815e-04
# Epoch 16/30
# 1499/1500 [============================>.] - ETA: 0s - loss: 5.1873 - acc: 2.5017e-04Epoch 00016: saving model to /content/gdrive/My Drive/Colab Notebooks/Курач/en-ru_standard_deps/e=30_b=16_d=2_h=256_emb=300/model/weights-16.h5
# 1500/1500 [==============================] - 687s 458ms/step - loss: 5.1873 - acc: 2.5000e-04 - val_loss: 2918.6623 - val_acc: 1.4815e-04
# Epoch 17/30
# 1499/1500 [============================>.] - ETA: 0s - loss: 5.1873 - acc: 2.5017e-04Epoch 00017: saving model to /content/gdrive/My Drive/Colab Notebooks/Курач/en-ru_standard_deps/e=30_b=16_d=2_h=256_emb=300/model/weights-17.h5
# 1500/1500 [==============================] - 688s 459ms/step - loss: 5.1873 - acc: 2.5000e-04 - val_loss: 2918.6623 - val_acc: 1.4815e-04
# Epoch 18/30
# 1499/1500 [============================>.] - ETA: 0s - loss: 5.1873 - acc: 2.5017e-04Epoch 00018: saving model to /content/gdrive/My Drive/Colab Notebooks/Курач/en-ru_standard_deps/e=30_b=16_d=2_h=256_emb=300/model/weights-18.h5
# 1500/1500 [==============================] - 689s 460ms/step - loss: 5.1873 - acc: 2.5000e-04 - val_loss: 2918.6623 - val_acc: 1.4815e-04
# Epoch 19/30
# 1499/1500 [============================>.] - ETA: 0s - loss: 5.1873 - acc: 2.5017e-04Epoch 00019: saving model to /content/gdrive/My Drive/Colab Notebooks/Курач/en-ru_standard_deps/e=30_b=16_d=2_h=256_emb=300/model/weights-19.h5
# 1500/1500 [==============================] - 689s 459ms/step - loss: 5.1873 - acc: 2.5000e-04 - val_loss: 2918.6623 - val_acc: 1.4815e-04
# Epoch 20/30
# 1499/1500 [============================>.] - ETA: 0s - loss: 5.1873 - acc: 2.5017e-04Epoch 00020: saving model to /content/gdrive/My Drive/Colab Notebooks/Курач/en-ru_standard_deps/e=30_b=16_d=2_h=256_emb=300/model/weights-20.h5
# 1500/1500 [==============================] - 688s 458ms/step - loss: 5.1873 - acc: 2.5000e-04 - val_loss: 2918.6623 - val_acc: 1.4815e-04
# Epoch 21/30
# 1499/1500 [============================>.] - ETA: 0s - loss: 5.1873 - acc: 2.5017e-04Epoch 00021: saving model to /content/gdrive/My Drive/Colab Notebooks/Курач/en-ru_standard_deps/e=30_b=16_d=2_h=256_emb=300/model/weights-21.h5
# 1500/1500 [==============================] - 689s 459ms/step - loss: 5.1873 - acc: 2.5000e-04 - val_loss: 2918.6623 - val_acc: 1.4815e-04
# Epoch 22/30
# 1499/1500 [============================>.] - ETA: 0s - loss: 5.1873 - acc: 2.5017e-04Epoch 00022: saving model to /content/gdrive/My Drive/Colab Notebooks/Курач/en-ru_standard_deps/e=30_b=16_d=2_h=256_emb=300/model/weights-22.h5
# 1500/1500 [==============================] - 686s 457ms/step - loss: 5.1873 - acc: 2.5000e-04 - val_loss: 2918.6623 - val_acc: 1.4815e-04
# Epoch 23/30
# 1499/1500 [============================>.] - ETA: 0s - loss: 5.1873 - acc: 2.5017e-04Epoch 00023: saving model to /content/gdrive/My Drive/Colab Notebooks/Курач/en-ru_standard_deps/e=30_b=16_d=2_h=256_emb=300/model/weights-23.h5
# 1500/1500 [==============================] - 686s 457ms/step - loss: 5.1873 - acc: 2.5000e-04 - val_loss: 2918.6623 - val_acc: 1.4815e-04
# Epoch 24/30
# 1499/1500 [============================>.] - ETA: 0s - loss: 5.1873 - acc: 2.5017e-04Epoch 00024: saving model to /content/gdrive/My Drive/Colab Notebooks/Курач/en-ru_standard_deps/e=30_b=16_d=2_h=256_emb=300/model/weights-24.h5
# 1500/1500 [==============================] - 685s 457ms/step - loss: 5.1873 - acc: 2.5000e-04 - val_loss: 2918.6623 - val_acc: 1.4815e-04
# Epoch 25/30
# 1499/1500 [============================>.] - ETA: 0s - loss: 5.1873 - acc: 2.5017e-04Epoch 00025: saving model to /content/gdrive/My Drive/Colab Notebooks/Курач/en-ru_standard_deps/e=30_b=16_d=2_h=256_emb=300/model/weights-25.h5
# 1500/1500 [==============================] - 686s 457ms/step - loss: 5.1873 - acc: 2.5000e-04 - val_loss: 2918.6623 - val_acc: 1.4815e-04
# Epoch 26/30
# 1499/1500 [============================>.] - ETA: 0s - loss: 5.1873 - acc: 2.5017e-04Epoch 00026: saving model to /content/gdrive/My Drive/Colab Notebooks/Курач/en-ru_standard_deps/e=30_b=16_d=2_h=256_emb=300/model/weights-26.h5
# 1500/1500 [==============================] - 686s 457ms/step - loss: 5.1873 - acc: 2.5000e-04 - val_loss: 2918.6623 - val_acc: 1.4815e-04
# Epoch 27/30
# 1499/1500 [============================>.] - ETA: 0s - loss: 5.1873 - acc: 2.5017e-04Epoch 00027: saving model to /content/gdrive/My Drive/Colab Notebooks/Курач/en-ru_standard_deps/e=30_b=16_d=2_h=256_emb=300/model/weights-27.h5
# 1500/1500 [==============================] - 687s 458ms/step - loss: 5.1873 - acc: 2.5000e-04 - val_loss: 2918.6623 - val_acc: 1.4815e-04
# Epoch 28/30
# 1499/1500 [============================>.] - ETA: 0s - loss: 5.1873 - acc: 2.5017e-04Epoch 00028: saving model to /content/gdrive/My Drive/Colab Notebooks/Курач/en-ru_standard_deps/e=30_b=16_d=2_h=256_emb=300/model/weights-28.h5
# 1500/1500 [==============================] - 686s 457ms/step - loss: 5.1873 - acc: 2.5000e-04 - val_loss: 2918.6623 - val_acc: 1.4815e-04
# Epoch 29/30
# 1499/1500 [============================>.] - ETA: 0s - loss: 5.1873 - acc: 2.5017e-04Epoch 00029: saving model to /content/gdrive/My Drive/Colab Notebooks/Курач/en-ru_standard_deps/e=30_b=16_d=2_h=256_emb=300/model/weights-29.h5
# 1500/1500 [==============================] - 686s 457ms/step - loss: 5.1873 - acc: 2.5000e-04 - val_loss: 2918.6623 - val_acc: 1.4815e-04
# Epoch 30/30
# 1499/1500 [============================>.] - ETA: 0s - loss: 5.1873 - acc: 2.5017e-04Epoch 00030: saving model to /content/gdrive/My Drive/Colab Notebooks/Курач/en-ru_standard_deps/e=30_b=16_d=2_h=256_emb=300/model/weights-30.h5
# 1500/1500 [==============================] - 687s 458ms/step - loss: 5.1873 - acc: 2.5000e-04 - val_loss: 2918.6623 - val_acc: 1.4815e-04

# %%
dump(history.history, open('{}/history.json'.format(config['data_path']), 'w'))

# %%
vis('acc', history)

# %%
add_config('best_epoch', 6, config=config, colab=True) #\\определять автоматически?
